# %%
import pandas as pd
import cdsapi
import netCDF4
from netCDF4 import num2date
import numpy as np
import os
import xarray as xr

# %%
def isFilePresent( file_name):
    file_present = os.path.isfile(file_name)
    if file_present:
        print('Alreaday present : '+file_name)
    else:
        print('file absent : '+file_name)
    return file_present

# %%
def download_climate_data_xarray(date, latitude, longitude, area, day_night_ind, result_df):
    
    c = cdsapi.Client()
    
    date_split = date.split("-")
    year = date_split[0]
    month = date_split[1]
    day = date_split[2]
    
    area_str = '_'.join(str(num) for num in area)
    
    file_name = './historical_climate_data/'+year+'/weather-'+str(longitude)+'-'+str(latitude)+'-'+date+'.nc'
    if not isFilePresent(file_name):
        
        time = '12:00'
        if day_night_ind == "N":
            time = '22:00'
        c.retrieve('reanalysis-era5-single-levels',
        {
            'product_type': 'reanalysis',
            'format': 'netcdf',
            'variable': [
            '10m_u_component_of_wind', '10m_v_component_of_wind', '2m_temperature',
            'soil_temperature_level_1', 'soil_temperature_level_2', 'soil_temperature_level_3',
            'soil_temperature_level_4', 'soil_type', 'total_precipitation', 'volumetric_soil_water_layer_1',
            'volumetric_soil_water_layer_2', 'volumetric_soil_water_layer_3', 'volumetric_soil_water_layer_4'
            ],
            'year': year,
            'month': month,
            'day': [str(day)],
            'time': [time],
            'area': area,
        },
        file_name)

    ds = xr.open_dataset(file_name)

    longitude = np.mean(ds['longitude'].values)
    latitude = np.mean(ds['latitude'].values)
    u10 = np.mean(ds['u10'].values)
    v10 = np.mean(ds['v10'].values)
    t2m = np.mean(ds['t2m'].values)
    stl1 = np.mean(ds['stl1'].values)
    stl2 = np.mean(ds['stl2'].values)
    stl3 = np.mean(ds['stl3'].values)
    stl4 = np.mean(ds['stl4'].values)
    slt = np.mean(ds['slt'].values)
    tp = np.mean(ds['tp'].values)
    swvl1 = np.mean(ds['swvl1'].values)
    swvl2 = np.mean(ds['swvl2'].values)
    swvl3 = np.mean(ds['swvl3'].values)
    swvl4 = np.mean(ds['swvl4'].values)

    new_row = {'longitude':longitude, 
           'latitude':latitude, 
           'date': date,       
           'daynight': day_night_ind,
           '10m_u_component_of_wind': u10,
           '10m_v_component_of_wind': v10,
           '2m_temperature': t2m,
           'soil_temperature_level_1': stl1,
           'soil_temperature_level_2': stl2,
           'soil_temperature_level_3': stl3,
           'soil_temperature_level_4': stl4,
           'soil_type': slt,
           'total_precipitation': tp,
           'volumetric_soil_water_layer_1': swvl1,
           'volumetric_soil_water_layer_2': swvl2,
           'volumetric_soil_water_layer_3': swvl3,
           'volumetric_soil_water_layer_4': swvl4}
    result_df.loc[len(result_df)] = new_row

# %%
def group_fire_data_xarray(file_name):
    file_path = "./historical_fire_data/" + file_name + ".csv"
    fire_data = pd.read_csv(file_path)
    
    filtered_fire_data = fire_data.query("`confidence` >= 75 and `type` == 0")
    grouped_fire_data = filtered_fire_data.groupby(['acq_date', 'daynight']).agg({'latitude':'mean','longitude':'mean','brightness':'mean','confidence':'mean', 'frp':'mean', 'bright_t31':'mean'}).reset_index()

    #grouped_fire_data.apply(apply_on_each_group)

    result_df = pd.DataFrame({'longitude': pd.Series(dtype='float'),
                   'latitude': pd.Series(dtype='float'),
                   'date': pd.Series(dtype='str'),       
                   'daynight': pd.Series(dtype='str'),                   
                   '10m_u_component_of_wind': pd.Series(dtype='float'),
                   '10m_v_component_of_wind': pd.Series(dtype='float'),
                   '2m_temperature': pd.Series(dtype='float'),
                   'soil_temperature_level_1': pd.Series(dtype='float'),
                   'soil_temperature_level_2': pd.Series(dtype='float'),
                   'soil_temperature_level_3': pd.Series(dtype='float'),
                   'soil_temperature_level_4': pd.Series(dtype='float'),
                   'soil_type': pd.Series(dtype='float'),
                   'total_precipitation': pd.Series(dtype='float'),
                   'volumetric_soil_water_layer_1': pd.Series(dtype='float'),
                   'volumetric_soil_water_layer_2': pd.Series(dtype='float'),
                   'volumetric_soil_water_layer_3': pd.Series(dtype='float'),
                   'volumetric_soil_water_layer_4': pd.Series(dtype='float')})
    
    #print(grouped_fire_data)
    for modis_data_index, modis_row in grouped_fire_data.iterrows():
        #print(modis_row['acq_date'])
        date_value = modis_row['acq_date']
        confidence = modis_row['confidence']
        latitude = modis_row['latitude']
        longitude = modis_row['longitude']
        day_night_ind = modis_row['daynight']
        #print(type(confidence))
        if confidence > 75:
            north_coord = latitude+0.25
            south_coord = latitude-0.25
            west_coord = longitude-0.25
            east_coord = longitude+0.25
            area = [north_coord, west_coord, south_coord, east_coord]
            #print(area)
            download_climate_data_xarray(date_value, latitude, longitude, area, day_night_ind, result_df)
    
    result_filename = "./historical_climate_data/csv/"+file_name+".csv"
    result_df.to_csv(result_filename)
    return result_filename

# %%
group_fire_data_xarray("canada_2022")
# Out:
# Alreaday present : ./historical_climate_data/2022/weather--120.7944-55.339499999999994-2022-01-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.60915-54.6095-2022-01-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.8242-54.606750000000005-2022-01-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.15755-54.888774999999995-2022-01-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.46225000000001-54.32155-2022-01-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.93253333333332-55.749766666666666-2022-01-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--114.1811-49.376-2022-01-18.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.5004-54.4232-2022-01-20.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.59049999999999-54.6407-2022-01-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.0083-53.0929-2022-01-23.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.9979-54.92835-2022-01-24.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.59685714285715-55.535671428571426-2022-01-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.6182-54.6035-2022-01-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.06273333333333-53.097095833333334-2022-01-27.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.89-55.5015-2022-01-29.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.1568-56.2799-2022-01-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.4367-55.21465-2022-01-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.28252499999999-55.330349999999996-2022-02-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--113.75743333333332-51.651199999999996-2022-02-07.nc
# Alreaday present : ./historical_climate_data/2022/weather--110.7732-56.3635-2022-02-07.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.5162-55.032085714285714-2022-02-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.02199999999999-55.1054-2022-02-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.38334-54.06024-2022-02-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.0404-55.1105-2022-02-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.48866666666667-53.352466666666665-2022-02-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.7455142857143-53.43658571428572-2022-02-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.257325-55.215675-2022-02-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.56530000000001-53.808099999999996-2022-02-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--124.3147-52.9056-2022-03-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.5064-50.579350000000005-2022-03-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.7611-49.8324-2022-03-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.461-52.03905-2022-03-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.1465-55.27405-2022-03-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.32462000000001-52.71694-2022-03-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--62.632600000000004-45.38074-2022-03-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.583125-55.561525-2022-03-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.54984999999999-52.34465-2022-03-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--114.63766666666668-52.599266666666665-2022-03-18.nc
# Alreaday present : ./historical_climate_data/2022/weather--113.9434-52.7443-2022-03-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.46835-53.4358-2022-03-23.nc
# Alreaday present : ./historical_climate_data/2022/weather--124.1773-53.2059-2022-03-24.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.3765-56.2836-2022-03-31.nc
# Alreaday present : ./historical_climate_data/2022/weather--113.8588-52.1764-2022-04-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.5146-52.91785-2022-04-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.0232-55.2029-2022-04-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--82.0522-42.4977-2022-04-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--80.7816-46.584-2022-04-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--98.9499-52.0957-2022-04-24.nc
# Alreaday present : ./historical_climate_data/2022/weather--80.46945-42.680800000000005-2022-04-28.nc
# Alreaday present : ./historical_climate_data/2022/weather--110.42180869565217-52.051243478260865-2022-05-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--103.54185-50.76725-2022-05-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--109.45728-50.181920000000005-2022-05-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--88.6377-48.75655-2022-05-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--74.028375-44.658675-2022-05-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--70.6292-46.1426-2022-05-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--65.95496499999999-44.02035-2022-05-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--65.6398-43.9654-2022-05-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--105.23193999999998-51.68856000000001-2022-05-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.8591-50.3373-2022-05-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--80.53160000000001-47.782266666666665-2022-05-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--81.36529999999999-47.5128-2022-05-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--81.3679-47.5234-2022-05-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--104.3068-50.665099999999995-2022-05-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--101.26908-52.18894-2022-05-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--108.12060000000001-53.13663333333333-2022-05-24.nc
# Alreaday present : ./historical_climate_data/2022/weather--101.78125-52.8986-2022-05-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--102.8968-49.9216-2022-05-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.62035-51.3408-2022-05-26.nc
# Alreaday present : ./historical_climate_data/2022/weather--98.57923333333333-50.6521-2022-05-27.nc
# Alreaday present : ./historical_climate_data/2022/weather--106.27590000000001-50.356449999999995-2022-05-28.nc
# Alreaday present : ./historical_climate_data/2022/weather--107.8021-53.0988-2022-05-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.7442-58.21939999999999-2022-06-01.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.9707-58.5813-2022-06-01.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.974-58.58185-2022-06-02.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.60711-60.37582999999999-2022-06-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.59287777777779-59.31137777777778-2022-06-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.04532777777779-59.69318333333334-2022-06-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--104.61744999999999-55.32425-2022-06-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.16163333333334-60.60806666666667-2022-06-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--104.66930666666667-55.35136-2022-06-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--112.8883625-56.261624999999995-2022-06-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--74.38213448275863-55.53732586206897-2022-06-07.nc
# Alreaday present : ./historical_climate_data/2022/weather--71.78309999999999-56.043425-2022-06-07.nc
# Alreaday present : ./historical_climate_data/2022/weather--71.72388235294117-58.00017058823529-2022-06-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--64.6518-58.553-2022-06-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--98.7755875-55.1026-2022-06-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--72.52460967741936-57.97976451612903-2022-06-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--104.63295-55.384550000000004-2022-06-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--99.22722-56.59102-2022-06-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--99.242425-56.581325-2022-06-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--103.6598-53.0285-2022-06-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--101.12070833333333-58.881499999999996-2022-06-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--102.6578-57.883849999999995-2022-06-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--109.49645757575757-59.330918181818184-2022-06-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--104.33283333333333-59.547777777777775-2022-06-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--71.99198214285714-52.98393928571429-2022-06-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--79.58138-56.55988-2022-06-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--103.05752631578947-59.461157894736836-2022-06-17.nc
# Alreaday present : ./historical_climate_data/2022/weather--108.98375-59.005399999999995-2022-06-17.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.66189999999999-58.71843333333334-2022-06-18.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.470503125-63.945421875-2022-06-19.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.31425909090909-61.575272727272726-2022-06-20.nc
# Alreaday present : ./historical_climate_data/2022/weather--127.6087-58.6039-2022-06-20.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.75094999999999-64.5446-2022-06-21.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.3643-61.9648-2022-06-21.nc
# Alreaday present : ./historical_climate_data/2022/weather--114.16825294117648-60.6803294117647-2022-06-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.8943-64.02834999999999-2022-06-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--114.14562000000001-60.79312-2022-06-23.nc
# Alreaday present : ./historical_climate_data/2022/weather--114.06791063829786-62.13731276595745-2022-06-24.nc
# Alreaday present : ./historical_climate_data/2022/weather--107.712575-58.44653333333333-2022-06-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--110.66337000000001-59.545669999999994-2022-06-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--130.762375-62.7859-2022-06-26.nc
# Alreaday present : ./historical_climate_data/2022/weather--108.30873103448276-60.010693103448276-2022-06-26.nc
# Alreaday present : ./historical_climate_data/2022/weather--124.54397837837837-62.467343243243235-2022-06-27.nc
# Alreaday present : ./historical_climate_data/2022/weather--124.03665000000001-63.80111000000001-2022-06-27.nc
# Alreaday present : ./historical_climate_data/2022/weather--127.22558965517241-62.59470689655172-2022-06-28.nc
# Alreaday present : ./historical_climate_data/2022/weather--124.06976666666667-62.37493333333333-2022-06-28.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.31067222222221-62.76799444444444-2022-06-29.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.55517894736843-62.580426315789474-2022-06-29.nc
# Alreaday present : ./historical_climate_data/2022/weather--113.92006875-59.528768750000005-2022-06-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.1016125-59.00118125-2022-06-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.96373863636363-62.364318181818184-2022-07-01.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.43706666666668-62.384688888888896-2022-07-01.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.34806627906977-61.40696453488372-2022-07-02.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.03378333333335-59.38825-2022-07-02.nc
# Alreaday present : ./historical_climate_data/2022/weather--129.9319830935252-62.742114388489206-2022-07-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--127.18174347826087-62.52045652173913-2022-07-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.17383882978724-63.11756143617021-2022-07-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--129.88838684210526-62.14030263157894-2022-07-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.27767186897881-63.143643159922924-2022-07-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--131.45712012578616-62.44653459119497-2022-07-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.95671159737418-63.249813347921226-2022-07-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.32796555555556-62.48388111111111-2022-07-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--124.49532735042736-62.987768376068374-2022-07-07.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.57351582278481-62.40594620253164-2022-07-07.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.78983569682153-64.3920564792176-2022-07-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.14214976958525-62.655-2022-07-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.08788-65.13447866666667-2022-07-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.67934468085107-64.10081914893617-2022-07-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--130.2455392857143-66.09259642857143-2022-07-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.17707999999999-61.48652-2022-07-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--131.94541875-66.583934375-2022-07-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--130.5126642857143-66.33634285714285-2022-07-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--111.9877078125-60.4654640625-2022-07-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--106.26772857142858-55.16802857142857-2022-07-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--105.66647926267281-57.570154838709676-2022-07-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--108.74314545454546-58.93901363636364-2022-07-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--104.71413894736841-56.21360526315789-2022-07-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--104.36817777777777-55.83116666666667-2022-07-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--107.35155341365463-56.51054497991968-2022-07-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--107.09401111111112-56.66203333333333-2022-07-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--106.72001250000001-55.80116-2022-07-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--103.60103725490195-56.318520915032686-2022-07-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--106.27612333333333-56.832056666666666-2022-07-17.nc
# Alreaday present : ./historical_climate_data/2022/weather--108.6431-55.336625-2022-07-17.nc
# Alreaday present : ./historical_climate_data/2022/weather--109.5900053030303-58.14572348484848-2022-07-18.nc
# Alreaday present : ./historical_climate_data/2022/weather--100.91598961038962-55.537332467532465-2022-07-18.nc
# Alreaday present : ./historical_climate_data/2022/weather--103.50331527777779-56.10264212962963-2022-07-19.nc
# Alreaday present : ./historical_climate_data/2022/weather--105.47359626168225-56.77781261682243-2022-07-19.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.43571071428572-59.852607142857146-2022-07-20.nc
# Alreaday present : ./historical_climate_data/2022/weather--106.36800828402367-56.63896863905325-2022-07-20.nc
# Alreaday present : ./historical_climate_data/2022/weather--110.94764117647058-54.83815882352941-2022-07-21.nc
# Alreaday present : ./historical_climate_data/2022/weather--114.52802-53.96782-2022-07-21.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.2760955882353-60.45638382352941-2022-07-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.1832-60.5556-2022-07-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.50528260869567-59.56121086956522-2022-07-23.nc
# Alreaday present : ./historical_climate_data/2022/weather--113.01482000000001-55.13388-2022-07-23.nc
# Alreaday present : ./historical_climate_data/2022/weather--73.91449999999999-49.5397-2022-07-24.nc
# Alreaday present : ./historical_climate_data/2022/weather--127.12951666666666-60.25997727272727-2022-07-24.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.61885714285714-63.238099999999996-2022-07-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--112.03559999999999-57.230945454545456-2022-07-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.313684-59.688264-2022-07-26.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.146525-58.674883333333334-2022-07-26.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.90969182692308-60.09199903846154-2022-07-27.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.65753647058824-60.20955235294118-2022-07-27.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.24345-52.89226666666667-2022-07-28.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.0928888888889-59.918622222222226-2022-07-28.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.28545-56.707675-2022-07-29.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.05588333333333-50.952400000000004-2022-07-29.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.65564347826087-51.977917391304345-2022-07-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.94782333333333-50.035740000000004-2022-07-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.82797272727272-49.34737272727273-2022-07-31.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.00068-50.72270666666667-2022-07-31.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.5981-49.62056666666667-2022-08-01.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.31087727272728-50.216936363636364-2022-08-01.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.48547619047619-51.068309523809525-2022-08-02.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.65672599999999-50.23767-2022-08-02.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.0384475-50.0093-2022-08-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.09163333333332-50.981316666666665-2022-08-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--104.24856282051282-58.81627692307693-2022-08-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.627325-63.029624999999996-2022-08-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.83494743589742-63.9811576923077-2022-08-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--101.3257-54.88751666666667-2022-08-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--96.07596428571428-55.62902857142857-2022-08-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--109.309048-61.265112-2022-08-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.79639-49.26623-2022-08-07.nc
# Alreaday present : ./historical_climate_data/2022/weather--60.36254615384615-49.99982307692308-2022-08-07.nc
# Alreaday present : ./historical_climate_data/2022/weather--82.020256-48.946828000000004-2022-08-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--69.78548888888889-48.78664444444444-2022-08-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.9595625-52.525075-2022-08-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--111.97989-54.96736-2022-08-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.76106875-55.28414375-2022-08-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.6388-59.58256666666667-2022-08-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.94552777777777-51.16271666666667-2022-08-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--113.0457696969697-57.68551212121213-2022-08-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.84915294117647-62.347535294117655-2022-08-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.94769999999998-59.0823-2022-08-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.10663333333333-60.38323703703704-2022-08-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.80064054054054-60.03807297297297-2022-08-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.51860847457627-59.02100169491525-2022-08-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.79009696969696-60.53655909090909-2022-08-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.0974-54.47593571428571-2022-08-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.40998679245283-58.937960377358486-2022-08-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--114.081535-52.88529-2022-08-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--110.4556888888889-54.55633888888889-2022-08-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.23614444444445-56.14218444444444-2022-08-17.nc
# Alreaday present : ./historical_climate_data/2022/weather--114.23655000000001-53.806725-2022-08-17.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.43988850574712-63.122476781609194-2022-08-18.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.72880746268658-61.04284776119403-2022-08-18.nc
# Alreaday present : ./historical_climate_data/2022/weather--114.23369115646257-59.02365510204082-2022-08-19.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.27882531328322-62.43047293233082-2022-08-19.nc
# Alreaday present : ./historical_climate_data/2022/weather--110.83281458333333-58.706069791666664-2022-08-20.nc
# Alreaday present : ./historical_climate_data/2022/weather--114.01481176470588-59.796241176470595-2022-08-20.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.29299999999999-56.88570512820513-2022-08-21.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.92960270270271-58.495935135135134-2022-08-21.nc
# Alreaday present : ./historical_climate_data/2022/weather--112.88875287356322-58.063451724137934-2022-08-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.82795161290322-59.39864838709677-2022-08-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.37781772151898-60.107682278481015-2022-08-23.nc
# Alreaday present : ./historical_climate_data/2022/weather--111.10398383838384-59.38834747474747-2022-08-23.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.27378973214286-60.1194625-2022-08-24.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.83626249999999-60.24282788461539-2022-08-24.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.8810693877551-59.7192093877551-2022-08-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.12335714285715-59.71664545454546-2022-08-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--113.87368152610442-58.66406305220883-2022-08-26.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.68119310344828-59.2429091954023-2022-08-26.nc
# Alreaday present : ./historical_climate_data/2022/weather--110.84664444444444-57.20509166666667-2022-08-27.nc
# Alreaday present : ./historical_climate_data/2022/weather--111.91622631578947-58.63255526315789-2022-08-27.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.42144-58.35214-2022-08-28.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.974215-59.75740499999999-2022-08-28.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.212825-60.390800000000006-2022-08-29.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.79433333333333-51.09149333333333-2022-08-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.34585000000001-56.87665-2022-08-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.911815-52.564535-2022-08-31.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.048925-51.3232-2022-08-31.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.0985911111111-54.982257777777775-2022-09-01.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.50686875-54.181615625-2022-09-01.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.64683195876289-52.132918556701036-2022-09-02.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.26628139534884-54.70158139534884-2022-09-02.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.6383596273292-53.79327080745342-2022-09-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.19014857142858-51.87763714285714-2022-09-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.37527543859649-52.19674385964912-2022-09-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.09529082568808-52.53378256880735-2022-09-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.70600833333333-52.56912500000001-2022-09-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--114.91489772727273-54.82650681818182-2022-09-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.738696-49.89522-2022-09-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.47327777777777-54.004807407407405-2022-09-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.86816481481482-50.36593333333334-2022-09-07.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.18757647058823-50.65138823529412-2022-09-07.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.91301212121212-50.667545454545454-2022-09-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.13793653846155-51.03364423076923-2022-09-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.05489090909091-54.73189545454545-2022-09-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.94464897959183-53.17851224489796-2022-09-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.73937658227847-54.38374430379747-2022-09-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.89256641221374-54.888339694656494-2022-09-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.15751475409836-52.88102131147541-2022-09-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.87067062937064-53.18785734265734-2022-09-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--112.95430909090909-51.983354545454546-2022-09-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.18742622950819-54.640083606557376-2022-09-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.313075-55.40058125-2022-09-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.32447272727272-54.662736363636355-2022-09-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.6372-57.541014634146336-2022-09-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.448525-55.53505-2022-09-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.96348021978022-56.7278065934066-2022-09-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.52748620689655-56.760675862068965-2022-09-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.99136000000001-60.327020000000005-2022-09-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.20371627906977-58.59795813953488-2022-09-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.65275-61.138275-2022-09-17.nc
# Alreaday present : ./historical_climate_data/2022/weather--110.58153333333333-59.499500000000005-2022-09-17.nc
# Alreaday present : ./historical_climate_data/2022/weather--106.2439-53.4363-2022-09-18.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.55652-52.950340000000004-2022-09-19.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.973-49.8683-2022-09-19.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.20293999999998-50.00444-2022-09-20.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.13392857142857-53.606614285714286-2022-09-20.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.25564166666668-54.92714166666667-2022-09-21.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.968325-49.863475-2022-09-21.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.74448461538461-57.73146153846154-2022-09-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--113.0464-51.31568333333333-2022-09-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.59081666666667-60.80560833333333-2022-09-23.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.62032888888888-60.83096444444444-2022-09-23.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.65679999999999-56.81986666666666-2022-09-24.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.79065-61.1591-2022-09-24.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.80307857142857-60.15206785714286-2022-09-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.64763333333333-55.7411-2022-09-26.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.60544999999999-61.13135-2022-09-26.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.90433939393938-59.034195454545454-2022-09-27.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.46382258064516-60.833461290322575-2022-09-27.nc
# Alreaday present : ./historical_climate_data/2022/weather--110.69750714285715-51.76522857142857-2022-09-28.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.65821666666666-57.544000000000004-2022-09-28.nc
# Alreaday present : ./historical_climate_data/2022/weather--114.2239-58.95756666666667-2022-09-29.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.30225-55.540925-2022-09-29.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.07900625-58.58401875-2022-09-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.02025-55.128150000000005-2022-09-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.9644-57.18584137931035-2022-10-01.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.43567297297297-60.90534864864865-2022-10-01.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.37864057971014-59.503357971014495-2022-10-02.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.6352294736842-60.204428421052626-2022-10-02.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.98742666666666-56.65886-2022-10-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.09140000000001-59.673842105263155-2022-10-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.61658181818183-56.651104545454544-2022-10-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.23445000000001-58.03445588235294-2022-10-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.59662-54.90242-2022-10-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.022-58.8861-2022-10-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.8106962962963-56.508640740740745-2022-10-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.27843846153846-56.11871538461538-2022-10-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.28905789473684-55.36711578947369-2022-10-07.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.34168695652174-56.04512608695652-2022-10-07.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.84282941176471-57.569900000000004-2022-10-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.4580375-56.380910416666666-2022-10-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.7173703125-58.7003515625-2022-10-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.44221153846154-58.12346153846154-2022-10-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.01620588235293-58.20928970588235-2022-10-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.82309043062202-58.133887081339715-2022-10-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.28628-57.75583-2022-10-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.6766923076923-55.72904615384615-2022-10-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--109.94085833333334-53.28896666666666-2022-10-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.84004999999999-55.11285-2022-10-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.9999057142857-56.91930571428571-2022-10-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.3459-50.6554-2022-10-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.01339444444446-52.53554444444445-2022-10-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.599832-56.201167999999996-2022-10-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.79660000000001-52.48395-2022-10-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.837025-50.99978125-2022-10-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.48904999999999-49.22695-2022-10-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.33637272727273-54.0165-2022-10-17.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.71721818181818-50.54496363636363-2022-10-17.nc
# Alreaday present : ./historical_climate_data/2022/weather--114.43806111111111-53.10373888888889-2022-10-18.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.37946666666666-52.14013333333333-2022-10-18.nc
# Alreaday present : ./historical_climate_data/2022/weather--113.88613829787235-52.45816170212766-2022-10-19.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.3532-51.43335714285714-2022-10-19.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.56909999999999-55.55605-2022-10-20.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.61194444444443-56.62490555555556-2022-10-20.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.8382-53.76525-2022-10-24.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.2972-55.1616-2022-10-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.78785-53.7695-2022-10-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.27187105263158-54.34662368421052-2022-10-27.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.90205-53.13945-2022-10-28.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.9768304347826-57.39743043478261-2022-10-28.nc
# Alreaday present : ./historical_climate_data/2022/weather--106.21449333333334-51.89387333333333-2022-10-29.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.5442-58.3692-2022-10-29.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.44954901960784-53.34185490196079-2022-10-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--124.69808181818183-53.60680909090909-2022-10-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.61654000000001-53.514711428571424-2022-10-31.nc
# Alreaday present : ./historical_climate_data/2022/weather--113.24180000000001-53.11555-2022-10-31.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.01223114754099-53.608713114754096-2022-11-01.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.3327-54.49615-2022-11-01.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.48838666666667-52.117838666666664-2022-11-02.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.27182352941178-55.77345882352942-2022-11-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.2786-55.1575-2022-11-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--105.59429999999999-51.52995757575757-2022-11-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.6439-57.81205-2022-11-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.09120952380951-49.30883333333333-2022-11-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--126.830175-53.692375-2022-11-05.nc
# Alreaday present : ./historical_climate_data/2022/weather--129.56656666666666-53.86756666666667-2022-11-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.1912-49.111-2022-11-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.7802-49.223000000000006-2022-11-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.65473999999999-49.89818-2022-11-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.2118-52.90148-2022-11-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.9911-48.9659-2022-11-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.0328-54.3981-2022-11-11.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.21642857142857-53.95798571428571-2022-11-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.27649696969698-53.18704242424242-2022-11-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.64670689655172-55.38186896551724-2022-11-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.85135-57.640975-2022-11-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.5949275-55.567997500000004-2022-11-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.67174-50.22846-2022-11-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.3080222222222-54.32523333333333-2022-11-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.77443333333333-49.48943333333333-2022-11-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.06960434782609-53.64613913043478-2022-11-17.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.9725-55.1919-2022-11-17.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.67463076923076-52.179261538461546-2022-11-18.nc
# Alreaday present : ./historical_climate_data/2022/weather--125.3116-49.4202-2022-11-18.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.3865125-53.174425-2022-11-19.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.2246-54.9025-2022-11-19.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.6051-55.2687-2022-11-20.nc
# Alreaday present : ./historical_climate_data/2022/weather--120.06307142857143-56.405276190476194-2022-11-21.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.20061785714286-56.077378571428575-2022-11-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.09066666666666-55.22593333333333-2022-11-22.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.18117058823529-55.9679-2022-11-23.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.68759375-53.8805625-2022-11-23.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.12139714285713-53.390702857142855-2022-11-24.nc
# Alreaday present : ./historical_climate_data/2022/weather--121.48670399999999-54.886696-2022-11-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.73255-50.2158-2022-11-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.01172380952382-53.25165714285714-2022-11-26.nc
# Alreaday present : ./historical_climate_data/2022/weather--110.73573333333333-52.736533333333334-2022-11-26.nc
# Alreaday present : ./historical_climate_data/2022/weather--124.06928333333333-49.33075-2022-11-27.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.39915714285713-53.249185714285716-2022-11-27.nc
# Alreaday present : ./historical_climate_data/2022/weather--117.7486-57.0605-2022-12-03.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.1636-56.4176-2022-12-04.nc
# Alreaday present : ./historical_climate_data/2022/weather--124.3678-52.8608-2022-12-06.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.4378-55.6172-2022-12-07.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.44673571428572-54.15813571428571-2022-12-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.71945-54.61345-2022-12-08.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.37176153846154-54.92199230769231-2022-12-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.52149-56.70218-2022-12-09.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.85155-52.42615000000001-2022-12-10.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.496025-53.376725-2022-12-12.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.8594-56.9095-2022-12-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--115.5624-54.6448-2022-12-13.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.28071818181819-54.30175909090909-2022-12-14.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.52256216216215-53.14294054054054-2022-12-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--116.09989999999999-54.0794-2022-12-15.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.38001666666666-52.65063333333333-2022-12-16.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.5763-54.0199-2022-12-25.nc
# Alreaday present : ./historical_climate_data/2022/weather--118.5122-54.0162-2022-12-29.nc
# Alreaday present : ./historical_climate_data/2022/weather--119.2409857142857-52.705528571428566-2022-12-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--123.5735-51.6084-2022-12-30.nc
# Alreaday present : ./historical_climate_data/2022/weather--122.4528-56.2125-2022-12-31.nc
# './historical_climate_data/csv/canada_2022.csv'
